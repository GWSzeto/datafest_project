# %%
import pandas as pd
import numpy as np

# %%
dest = pd.read_csv("dest.txt", sep='\t')

# %%
dest.head()
# Out:
#    srch_destination_id                              srch_destination_name  \
# 0                 7997                                    Annaba, Algeria
# 1                 8090                       Al Ain, United Arab Emirates
# 2                 8121                                      Anapa, Russia
# 3                 8152                     Aarhus (and vicinity), Denmark
# 4                 8369  Abilene (and vicinity), Texas, United States o...
#
#    srch_destination_type_id  srch_destination_latitude  \
# 0                       557                  36.913930
# 1                       557                  24.231660
# 2                       557                  44.942840
# 3                       464                  56.153090
# 4                       464                  32.412406
#
#    srch_destination_longitude  popular_activity_adventure  \
# 0                    7.741176                   -2.181690
# 1                   55.740160                   -2.183490
# ...
